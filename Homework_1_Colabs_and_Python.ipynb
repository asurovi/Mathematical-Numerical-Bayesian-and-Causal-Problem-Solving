# %% [markdown]
# <a href="https://colab.research.google.com/github/asurovi/Mathematical-Numerical-Bayesian-and-Causal-Problem-Solving/blob/main/Homework_1_Colabs_and_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MSE 510 — Homework 1 (Colabs and Python)
#
# **Name:** Agnila Ghosh Surovi
# **Department:** Mechanical and Aerospace Engineering
# **Date:** 1/29/2026

# %% [markdown]
# I am familiar with Python.
